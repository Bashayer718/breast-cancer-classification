# %% [markdown]
# # The augmentation experiment

# %% [markdown]
# ## Data Preparation and Splitting for Training and Testing Sets

# %%
import os
import cv2
import torch
import numpy as np
from torch.utils.data import DataLoader, TensorDataset, random_split
import torchvision.transforms as transforms
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from sklearn.model_selection import train_test_split

# Set random seed for reproducibility
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)

# Define transformations
transform = transforms.Compose([
    transforms.ToPILImage(),              # Convert NumPy array to PIL Image
    transforms.Resize((256, 256)),        # Resize to fixed dimensions (256x256)
    transforms.ToTensor(),                # Convert to Tensor
    transforms.Normalize(mean=[0.5], std=[0.5])  # Normalize for grayscale (mean=0.5, std=0.5)
])


# Dataset path and categories
dataset_dir = "Augmented_data"
categories = ['normal', 'benign', 'malignant']

# Load images and labels
images = []
labels = []

for category in categories:
    path = os.path.join(dataset_dir, category)
    class_num = categories.index(category)
    for img_name in os.listdir(path):
        if '_mask' not in img_name:
            img_path = os.path.join(path, img_name)
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = transform(img)  # Apply transformations
            images.append(img)
            labels.append(class_num)


# Convert lists to tensors
images_tensor = torch.stack(images)
labels_tensor = torch.tensor(labels)

# Split the dataset into training and testing sets
train_images, test_images, train_labels, test_labels = train_test_split(
    images_tensor, labels_tensor, test_size=0.2, random_state=random_seed, stratify=labels_tensor)


# # Split the dataset into training and validation sets
# train_size = int(0.8 * len(images_tensor))  # 80% for training
# val_size = len(images_tensor) - train_size  # 20% for validation
# train_dataset, val_dataset = random_split(TensorDataset(images_tensor, labels_tensor), [train_size, val_size])
# Create datasets
train_dataset = TensorDataset(train_images, train_labels)
test_dataset = TensorDataset(test_images, test_labels)

# Save the training and testing data into separate files for consistency
train_data_path = "train_data_Augmented.pt"
test_data_path = "test_data_Augmented.pt"
torch.save(train_dataset, train_data_path)
torch.save(test_dataset, test_data_path)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"Train data saved at: {train_data_path}")
print(f"Test data saved at: {test_data_path}")
print(f"Training samples: {len(train_dataset)}, Testing samples: {len(test_dataset)}")
# Out:
# Train data saved at: /home/maryam.alshehyari/Documents/training/train_data_Augmented.pt
# Test data saved at: /home/maryam.alshehyari/Documents/training/test_data_Augmented.pt
# Training samples: 1061, Testing samples: 266

# %% [markdown]
# ## Training and Validation of DenseNet12

# %%
import os
import cv2
import torch
import numpy as np
from torch.utils.data import DataLoader, TensorDataset, random_split
import torchvision.transforms as transforms
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from sklearn.model_selection import train_test_split


# Set random seed for reproducibility
random_seed = 42
torch.manual_seed(random_seed)

# Paths to the saved .pt files
train_data_path = "train_data_Augmented.pt"
test_data_path = "test_data_Augmented.pt"
# Load the pre-saved datasets
train_dataset = torch.load(train_data_path)
test_dataset = torch.load(test_data_path)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)  # No shuffling for validation

# Load the pre-trained DenseNet121 model
model = models.densenet121(pretrained=True)

# Modify the classifier for 3 classes
num_classes = 3
model.classifier = nn.Linear(model.classifier.in_features, num_classes)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define the loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Lists to track training and validation metrics
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Training loop with validation
num_epochs = 100  # Set the number of epochs
best_val = 0.0  
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0  # Track the loss for this epoch
    correct_train = 0
    total_train = 0

    # Training phase
    for images, labels in train_loader:
        # Convert 1-channel grayscale images to 3-channel RGB
 
        images, labels = images.to(device), labels.to(device)  # Move data to the same device as model

        optimizer.zero_grad()  # Zero the parameter gradients

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Accumulate loss
        running_loss += loss.item() * images.size(0)

        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    # Calculate average training loss
    train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)
    
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

    # Validation phase
    model.eval()  # Set model to evaluation mode
    validation_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():  # Disable gradient calculation for validation
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            validation_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # Calculate average validation loss and accuracy
    # best_val = 0.0  # Initialize the best validation accuracy
    avg_val_loss = validation_loss / len(val_loader.dataset)
    accuracy = 100 * correct / total
    if accuracy > best_val:
        best_val = accuracy
        torch.save(model.state_dict(), "densenet121_ultrasound_aug.pth")

    val_losses.append(avg_val_loss)
    val_accuracies.append(accuracy)
    print(f"Validation Loss: {avg_val_loss:.4f}, Accuracy: {accuracy:.2f}%")

# Save the final model (optional)
# torch.save(model.state_dict(), "/home/maryam.alshehyari/Documents/training/densenet121_ultrasound.pth")
print(f"Best Validation Accuracy: {best_val:.2f}%")
# Out:
# /tmp/ipykernel_3910419/3145454920.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_dataset = torch.load(train_data_path)
# /tmp/ipykernel_3910419/3145454920.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_dataset = torch.load(test_data_path)
# /home/maryam.alshehyari/Documents/training/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/maryam.alshehyari/Documents/training/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100, Training Loss: 0.6274, Training Accuracy: 72.48%
# Validation Loss: 0.4716, Accuracy: 82.71%
# Epoch 2/100, Training Loss: 0.4288, Training Accuracy: 84.35%
# Validation Loss: 0.6170, Accuracy: 77.82%
# Epoch 3/100, Training Loss: 0.2698, Training Accuracy: 90.48%
# Validation Loss: 0.4256, Accuracy: 82.71%
# Epoch 4/100, Training Loss: 0.3651, Training Accuracy: 85.86%
# Validation Loss: 0.6634, Accuracy: 75.56%
# Epoch 5/100, Training Loss: 0.3013, Training Accuracy: 88.12%
# Validation Loss: 1.8238, Accuracy: 66.54%
# Epoch 6/100, Training Loss: 0.2601, Training Accuracy: 90.57%
# Validation Loss: 0.5470, Accuracy: 86.47%
# Epoch 7/100, Training Loss: 0.2525, Training Accuracy: 90.01%
# Validation Loss: 0.3045, Accuracy: 86.84%
# Epoch 8/100, Training Loss: 0.1419, Training Accuracy: 94.63%
# Validation Loss: 0.4386, Accuracy: 83.46%
# Epoch 9/100, Training Loss: 0.2057, Training Accuracy: 92.18%
# Validation Loss: 1.1986, Accuracy: 72.93%
# Epoch 10/100, Training Loss: 0.3105, Training Accuracy: 87.65%
# Validation Loss: 0.4918, Accuracy: 84.96%
# Epoch 11/100, Training Loss: 0.2187, Training Accuracy: 91.89%
# Validation Loss: 0.3436, Accuracy: 88.35%
# Epoch 12/100, Training Loss: 0.1832, Training Accuracy: 93.69%
# Validation Loss: 0.3273, Accuracy: 88.72%
# Epoch 13/100, Training Loss: 0.0681, Training Accuracy: 98.02%
# Validation Loss: 0.3126, Accuracy: 90.60%
# Epoch 14/100, Training Loss: 0.0773, Training Accuracy: 97.17%
# Validation Loss: 0.3812, Accuracy: 87.22%
# Epoch 15/100, Training Loss: 0.0633, Training Accuracy: 97.93%
# Validation Loss: 0.3961, Accuracy: 90.98%
# Epoch 16/100, Training Loss: 0.1331, Training Accuracy: 94.82%
# Validation Loss: 0.4811, Accuracy: 86.84%
# Epoch 17/100, Training Loss: 0.2493, Training Accuracy: 91.61%
# Validation Loss: 0.4911, Accuracy: 83.46%
# Epoch 18/100, Training Loss: 0.1408, Training Accuracy: 94.91%
# Validation Loss: 0.5339, Accuracy: 85.34%
# Epoch 19/100, Training Loss: 0.0740, Training Accuracy: 97.27%
# Validation Loss: 0.3610, Accuracy: 87.97%
# Epoch 20/100, Training Loss: 0.1727, Training Accuracy: 92.74%
# Validation Loss: 0.6450, Accuracy: 81.58%
# Epoch 21/100, Training Loss: 0.1669, Training Accuracy: 93.50%
# Validation Loss: 0.3315, Accuracy: 89.85%
# Epoch 22/100, Training Loss: 0.0841, Training Accuracy: 97.36%
# Validation Loss: 0.2695, Accuracy: 91.35%
# Epoch 23/100, Training Loss: 0.0394, Training Accuracy: 98.96%
# Validation Loss: 0.4576, Accuracy: 87.22%
# Epoch 24/100, Training Loss: 0.0622, Training Accuracy: 98.02%
# Validation Loss: 0.3578, Accuracy: 89.85%
# Epoch 25/100, Training Loss: 0.0488, Training Accuracy: 98.21%
# Validation Loss: 0.4123, Accuracy: 88.72%
# Epoch 26/100, Training Loss: 0.0288, Training Accuracy: 99.25%
# Validation Loss: 0.3356, Accuracy: 92.48%
# Epoch 27/100, Training Loss: 0.0412, Training Accuracy: 98.77%
# Validation Loss: 0.3833, Accuracy: 90.23%
# Epoch 28/100, Training Loss: 0.0541, Training Accuracy: 98.59%
# Validation Loss: 0.4582, Accuracy: 89.47%
# Epoch 29/100, Training Loss: 0.0200, Training Accuracy: 99.34%
# Validation Loss: 0.3792, Accuracy: 89.10%
# Epoch 30/100, Training Loss: 0.0148, Training Accuracy: 99.53%
# Validation Loss: 0.4336, Accuracy: 90.60%
# Epoch 31/100, Training Loss: 0.0299, Training Accuracy: 99.15%
# Validation Loss: 0.3990, Accuracy: 90.98%
# Epoch 32/100, Training Loss: 0.3090, Training Accuracy: 90.29%
# Validation Loss: 0.8023, Accuracy: 77.44%
# Epoch 33/100, Training Loss: 0.2555, Training Accuracy: 90.67%
# Validation Loss: 0.7777, Accuracy: 82.33%
# Epoch 34/100, Training Loss: 0.1254, Training Accuracy: 95.85%
# Validation Loss: 0.3673, Accuracy: 87.22%
# Epoch 35/100, Training Loss: 0.1948, Training Accuracy: 93.40%
# Validation Loss: 0.3565, Accuracy: 87.22%
# Epoch 36/100, Training Loss: 0.0763, Training Accuracy: 97.08%
# Validation Loss: 0.3234, Accuracy: 90.60%
# Epoch 37/100, Training Loss: 0.0981, Training Accuracy: 96.42%
# Validation Loss: 0.6918, Accuracy: 81.20%
# Epoch 38/100, Training Loss: 0.0858, Training Accuracy: 97.08%
# Validation Loss: 0.4638, Accuracy: 89.10%
# Epoch 39/100, Training Loss: 0.0344, Training Accuracy: 99.25%
# Validation Loss: 0.3909, Accuracy: 90.98%
# Epoch 40/100, Training Loss: 0.0215, Training Accuracy: 99.53%
# Validation Loss: 0.3979, Accuracy: 89.85%
# Epoch 41/100, Training Loss: 0.0342, Training Accuracy: 98.96%
# Validation Loss: 0.3834, Accuracy: 89.47%
# Epoch 42/100, Training Loss: 0.0288, Training Accuracy: 99.15%
# Validation Loss: 0.3626, Accuracy: 90.60%
# Epoch 43/100, Training Loss: 0.0168, Training Accuracy: 99.62%
# Validation Loss: 0.3122, Accuracy: 92.86%
# Epoch 44/100, Training Loss: 0.1676, Training Accuracy: 94.53%
# Validation Loss: 0.8773, Accuracy: 80.08%
# Epoch 45/100, Training Loss: 0.2524, Training Accuracy: 91.42%
# Validation Loss: 0.4363, Accuracy: 89.10%
# Epoch 46/100, Training Loss: 0.1609, Training Accuracy: 93.12%
# Validation Loss: 0.3513, Accuracy: 89.85%
# Epoch 47/100, Training Loss: 0.0328, Training Accuracy: 99.25%
# Validation Loss: 0.2915, Accuracy: 90.60%
# Epoch 48/100, Training Loss: 0.0270, Training Accuracy: 99.34%
# Validation Loss: 0.2906, Accuracy: 93.98%
# Epoch 49/100, Training Loss: 0.0165, Training Accuracy: 99.62%
# Validation Loss: 0.3377, Accuracy: 92.86%
# Epoch 50/100, Training Loss: 0.0491, Training Accuracy: 98.87%
# Validation Loss: 0.3717, Accuracy: 89.85%
# Epoch 51/100, Training Loss: 0.0210, Training Accuracy: 99.53%
# Validation Loss: 0.3754, Accuracy: 88.35%
# Epoch 52/100, Training Loss: 0.0156, Training Accuracy: 99.53%
# Validation Loss: 0.3127, Accuracy: 91.73%
# Epoch 53/100, Training Loss: 0.0122, Training Accuracy: 99.62%
# Validation Loss: 0.3135, Accuracy: 91.73%
# Epoch 54/100, Training Loss: 0.0130, Training Accuracy: 99.72%
# Validation Loss: 0.3217, Accuracy: 92.48%
# Epoch 55/100, Training Loss: 0.0394, Training Accuracy: 98.59%
# Validation Loss: 0.2933, Accuracy: 92.86%
# Epoch 56/100, Training Loss: 0.0522, Training Accuracy: 98.30%
# Validation Loss: 0.3871, Accuracy: 88.72%
# Epoch 57/100, Training Loss: 0.0605, Training Accuracy: 97.55%
# Validation Loss: 0.5381, Accuracy: 86.47%
# Epoch 58/100, Training Loss: 0.0321, Training Accuracy: 98.96%
# Validation Loss: 0.2711, Accuracy: 92.11%
# Epoch 59/100, Training Loss: 0.0112, Training Accuracy: 99.43%
# Validation Loss: 0.2298, Accuracy: 92.48%
# Epoch 60/100, Training Loss: 0.0100, Training Accuracy: 99.62%
# Validation Loss: 0.2867, Accuracy: 93.23%
# Epoch 61/100, Training Loss: 0.1135, Training Accuracy: 95.57%
# Validation Loss: 0.4634, Accuracy: 87.97%
# Epoch 62/100, Training Loss: 0.0888, Training Accuracy: 96.51%
# Validation Loss: 0.5430, Accuracy: 87.97%
# Epoch 63/100, Training Loss: 0.1182, Training Accuracy: 95.76%
# Validation Loss: 0.5444, Accuracy: 89.47%
# Epoch 64/100, Training Loss: 0.0448, Training Accuracy: 98.49%
# Validation Loss: 0.3506, Accuracy: 93.23%
# Epoch 65/100, Training Loss: 0.0173, Training Accuracy: 99.72%
# Validation Loss: 0.3404, Accuracy: 92.11%
# Epoch 66/100, Training Loss: 0.0112, Training Accuracy: 99.91%
# Validation Loss: 0.3252, Accuracy: 91.73%
# Epoch 67/100, Training Loss: 0.0236, Training Accuracy: 98.96%
# Validation Loss: 0.4606, Accuracy: 90.98%
# Epoch 68/100, Training Loss: 0.0596, Training Accuracy: 97.83%
# Validation Loss: 0.5451, Accuracy: 86.09%
# Epoch 69/100, Training Loss: 0.1099, Training Accuracy: 95.57%
# Validation Loss: 0.5797, Accuracy: 86.09%
# Epoch 70/100, Training Loss: 0.0400, Training Accuracy: 98.59%
# Validation Loss: 0.6097, Accuracy: 86.84%
# Epoch 71/100, Training Loss: 0.0274, Training Accuracy: 98.96%
# Validation Loss: 0.4244, Accuracy: 90.98%
# Epoch 72/100, Training Loss: 0.0118, Training Accuracy: 99.62%
# Validation Loss: 0.3793, Accuracy: 90.60%
# Epoch 73/100, Training Loss: 0.0060, Training Accuracy: 99.81%
# Validation Loss: 0.3489, Accuracy: 92.48%
# Epoch 74/100, Training Loss: 0.0080, Training Accuracy: 99.91%
# Validation Loss: 0.4531, Accuracy: 91.73%
# Epoch 75/100, Training Loss: 0.1386, Training Accuracy: 96.14%
# Validation Loss: 0.4791, Accuracy: 89.85%
# Epoch 76/100, Training Loss: 0.0576, Training Accuracy: 98.40%
# Validation Loss: 0.3553, Accuracy: 90.23%
# Epoch 77/100, Training Loss: 0.2011, Training Accuracy: 93.12%
# Validation Loss: 0.7695, Accuracy: 80.83%
# Epoch 78/100, Training Loss: 0.1692, Training Accuracy: 94.53%
# Validation Loss: 0.4109, Accuracy: 89.10%
# Epoch 79/100, Training Loss: 0.0460, Training Accuracy: 98.59%
# Validation Loss: 0.3431, Accuracy: 90.60%
# Epoch 80/100, Training Loss: 0.0339, Training Accuracy: 98.68%
# Validation Loss: 0.6366, Accuracy: 82.71%
# Epoch 81/100, Training Loss: 0.1057, Training Accuracy: 96.14%
# Validation Loss: 0.5471, Accuracy: 86.84%
# Epoch 82/100, Training Loss: 0.0463, Training Accuracy: 98.59%
# Validation Loss: 0.4285, Accuracy: 89.85%
# Epoch 83/100, Training Loss: 0.0453, Training Accuracy: 98.59%
# Validation Loss: 0.6018, Accuracy: 90.60%
# Epoch 84/100, Training Loss: 0.1650, Training Accuracy: 94.63%
# Validation Loss: 0.2529, Accuracy: 91.73%
# Epoch 85/100, Training Loss: 0.0421, Training Accuracy: 98.49%
# Validation Loss: 0.2921, Accuracy: 92.11%
# Epoch 86/100, Training Loss: 0.0441, Training Accuracy: 98.77%
# Validation Loss: 0.5020, Accuracy: 89.10%
# Epoch 87/100, Training Loss: 0.0177, Training Accuracy: 99.34%
# Validation Loss: 0.3455, Accuracy: 91.35%
# Epoch 88/100, Training Loss: 0.0707, Training Accuracy: 97.64%
# Validation Loss: 0.3201, Accuracy: 89.47%
# Epoch 89/100, Training Loss: 0.0183, Training Accuracy: 99.43%
# Validation Loss: 0.3144, Accuracy: 91.35%
# Epoch 90/100, Training Loss: 0.0502, Training Accuracy: 98.02%
# Validation Loss: 0.6337, Accuracy: 87.22%
# Epoch 91/100, Training Loss: 0.0186, Training Accuracy: 99.62%
# Validation Loss: 0.4739, Accuracy: 90.23%
# Epoch 92/100, Training Loss: 0.0926, Training Accuracy: 97.27%
# Validation Loss: 0.4823, Accuracy: 86.84%
# Epoch 93/100, Training Loss: 0.0702, Training Accuracy: 97.08%
# Validation Loss: 0.5577, Accuracy: 87.59%
# Epoch 94/100, Training Loss: 0.0178, Training Accuracy: 99.53%
# Validation Loss: 0.5040, Accuracy: 89.47%
# Epoch 95/100, Training Loss: 0.0083, Training Accuracy: 99.72%
# Validation Loss: 0.4302, Accuracy: 90.23%
# Epoch 96/100, Training Loss: 0.0087, Training Accuracy: 99.62%
# Validation Loss: 0.5144, Accuracy: 91.35%
# Epoch 97/100, Training Loss: 0.0832, Training Accuracy: 96.61%
# Validation Loss: 0.6422, Accuracy: 85.34%
# Epoch 98/100, Training Loss: 0.1209, Training Accuracy: 96.51%
# Validation Loss: 0.2984, Accuracy: 90.60%
# Epoch 99/100, Training Loss: 0.0795, Training Accuracy: 97.64%
# Validation Loss: 0.3115, Accuracy: 91.35%
# Epoch 100/100, Training Loss: 0.0374, Training Accuracy: 99.15%
# Validation Loss: 0.3470, Accuracy: 91.35%
# Best Validation Accuracy: 93.98%

# %% [markdown]
# ## Visualizing Training and Validation Metrics for Model Performance

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()
